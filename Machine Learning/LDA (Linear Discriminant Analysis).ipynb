# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.datasets import load_iris
from sklearn.preprocessing import StandardScaler
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis as LDA

# %%
# Load Iris dataset
iris = load_iris()
X = iris.data
y = iris.target
target_names = iris.target_names

# Standardize the features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
# Apply LDA
lda = LDA(n_components=2)
X_lda = lda.fit_transform(X_scaled, y)

# Create DataFrame for plotting
df_lda = pd.DataFrame(X_lda, columns=['LD1', 'LD2'])
df_lda['Target'] = y

# %%
plt.figure(figsize=(8, 6))
sns.scatterplot(data=df_lda, x='LD1', y='LD2', hue='Target', palette='Set1', s=80)
plt.title('LDA: Iris Dataset (2D Projection)')
plt.xlabel('Linear Discriminant 1')
plt.ylabel('Linear Discriminant 2')
plt.grid(True)
plt.show()

# %%
print("Explained variance ratio of LDA components:")
for i, ratio in enumerate(lda.explained_variance_ratio_):
    print(f"LD{i+1}: {ratio:.4f}")
# Out:
# Explained variance ratio of LDA components:
# LD1: 0.9912
# LD2: 0.0088
